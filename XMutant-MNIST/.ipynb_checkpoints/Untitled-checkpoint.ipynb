# %%
import os
cwd = os.getcwd()
print(cwd)
# %matplotlib inline
# Out:
# /home/xchen/Projects/deepjanus-pri/XMutant-MNIST

# %% [markdown]
# # 1. Try vectorization tools here

# %%
import h5py
import matplotlib.pyplot as plt
from config import NGEN, \
    POPSIZE, INITIALPOP, \
    RESEEDUPPERBOUND, GENERATE_ONE_ONLY, DATASET, \
    STOP_CONDITION, STEPSIZE, DJ_DEBUG, MUTATION_TYPE
import numpy as np
# Load the dataset.
hf = h5py.File(DATASET, 'r')
x_test = hf.get('xn')
x_test = np.array(x_test)
y_test = hf.get('yn')
y_test = np.array(y_test)

x = x_test[1]
y = y_test[1]

x_test,y_test

    
plt.imshow(x)
plt.title("Label"+str(y))
plt.show()

# %% [markdown]
# Try vectorization tools here

# %%
from vectorization_tools import *

# thresholding
bw = preprocess(x)
plt.subplot(1,2,1)
plt.imshow(bw)
plt.title("Thresholding number "+str(y))
# Out:
# Text(0.5, 1.0, 'Thresholding number 5')

# %%
# vertorizing
# Create a bitmap from the array
bmp = potrace.Bitmap(bw)
# Trace the bitmap to a path
path = bmp.trace()
desc = createSVGpath(path)
svg_xml = create_svg_xml(desc)
print(path)
print("----------------------PATH--------------------")
print(desc)
print("----------------------DESC--------------------")
print(svg_xml) # also the result of vectorize(x)
print("----------------------Control Points--------------------")
root = ET.fromstring(svg_xml)
NAMESPACE = '{http://www.w3.org/2000/svg}'
svg_path = root.find(NAMESPACE + 'path').get('d')

print(svg_path)
# Out:
# <potrace._potrace.Path object at 0x7fcb3c09d500>
# ----------------------PATH--------------------
#  M 9.51727354110616,23.866822442360682 C 7.326773988714548,23.35407099427908 5.080535634789604,22.4805356347896 4.525632754606285,21.925632754606283 C 2.8631039142417585,20.263103914241764 5.922023034797406,19.117247821398927 9.377320857176409,20.10821419798448 C 14.307346962865184,21.52212708120532 20.0,21.23446572137142 20.0,19.571428571428573 C 20.0,15.448883661542762 14.21768735115364,13.80182900831094 9.07712424347698,16.460117503694516 C 7.524168496961943,17.263182130726502 5.971515464059835,17.638182130726502 5.626784170361184,17.293450837027848 C 4.509391136402156,16.176057803068822 4.962136189569638,11.973900681682284 6.525680146231596,8.950340073115797 C 7.848028337137488,6.393200643938476 8.614348031347701,5.998533242264358 12.275680146231595,5.988994336118905 C 14.599056065804218,5.982941220984303 18.1875,5.69906215134539 20.25,5.358151959143543 C 23.575019504115325,4.808560183035496 24.0,4.972855689457036 24.0,6.80788472346307 C 24.0,8.47943353024978 23.18263780528935,8.995855833947624 19.75,9.493101638215052 C 17.4125,9.831707728751054 14.42460457428058,9.97178053355376 13.11023238729018,9.804374537776619 C 11.79586020029978,9.636968541999478 10.52086020029978,10.0625 10.276899053956846,10.750000000000002 C 9.984878902308747,11.57293372230617 10.870687678108958,12.000000000000004 12.86961364554084,12.000000000000004 C 21.55766519650088,11.999999999999998 27.39996126093298,19.505166496923657 21.777493756594573,23.443296031350947 C 19.329211882382396,25.158139407501768 15.586222427783175,25.28744009397321 9.51727354110616,23.866822442360682 Z
# ----------------------DESC--------------------
# <svg version="1.0" xmlns="http://www.w3.org/2000/svg" height="28" width="28"><path d=" M 9.51727354110616,23.866822442360682 C 7.326773988714548,23.35407099427908 5.080535634789604,22.4805356347896 4.525632754606285,21.925632754606283 C 2.8631039142417585,20.263103914241764 5.922023034797406,19.117247821398927 9.377320857176409,20.10821419798448 C 14.307346962865184,21.52212708120532 20.0,21.23446572137142 20.0,19.571428571428573 C 20.0,15.448883661542762 14.21768735115364,13.80182900831094 9.07712424347698,16.460117503694516 C 7.524168496961943,17.263182130726502 5.971515464059835,17.638182130726502 5.626784170361184,17.293450837027848 C 4.509391136402156,16.176057803068822 4.962136189569638,11.973900681682284 6.525680146231596,8.950340073115797 C 7.848028337137488,6.393200643938476 8.614348031347701,5.998533242264358 12.275680146231595,5.988994336118905 C 14.599056065804218,5.982941220984303 18.1875,5.69906215134539 20.25,5.358151959143543 C 23.575019504115325,4.808560183035496 24.0,4.972855689457036 24.0,6.80788472346307 C 24.0,8.47943353024978 23.18263780528935,8.995855833947624 19.75,9.493101638215052 C 17.4125,9.831707728751054 14.42460457428058,9.97178053355376 13.11023238729018,9.804374537776619 C 11.79586020029978,9.636968541999478 10.52086020029978,10.0625 10.276899053956846,10.750000000000002 C 9.984878902308747,11.57293372230617 10.870687678108958,12.000000000000004 12.86961364554084,12.000000000000004 C 21.55766519650088,11.999999999999998 27.39996126093298,19.505166496923657 21.777493756594573,23.443296031350947 C 19.329211882382396,25.158139407501768 15.586222427783175,25.28744009397321 9.51727354110616,23.866822442360682 Z" /></svg>
# ----------------------Control Points--------------------
#  M 9.51727354110616,23.866822442360682 C 7.326773988714548,23.35407099427908 5.080535634789604,22.4805356347896 4.525632754606285,21.925632754606283 C 2.8631039142417585,20.263103914241764 5.922023034797406,19.117247821398927 9.377320857176409,20.10821419798448 C 14.307346962865184,21.52212708120532 20.0,21.23446572137142 20.0,19.571428571428573 C 20.0,15.448883661542762 14.21768735115364,13.80182900831094 9.07712424347698,16.460117503694516 C 7.524168496961943,17.263182130726502 5.971515464059835,17.638182130726502 5.626784170361184,17.293450837027848 C 4.509391136402156,16.176057803068822 4.962136189569638,11.973900681682284 6.525680146231596,8.950340073115797 C 7.848028337137488,6.393200643938476 8.614348031347701,5.998533242264358 12.275680146231595,5.988994336118905 C 14.599056065804218,5.982941220984303 18.1875,5.69906215134539 20.25,5.358151959143543 C 23.575019504115325,4.808560183035496 24.0,4.972855689457036 24.0,6.80788472346307 C 24.0,8.47943353024978 23.18263780528935,8.995855833947624 19.75,9.493101638215052 C 17.4125,9.831707728751054 14.42460457428058,9.97178053355376 13.11023238729018,9.804374537776619 C 11.79586020029978,9.636968541999478 10.52086020029978,10.0625 10.276899053956846,10.750000000000002 C 9.984878902308747,11.57293372230617 10.870687678108958,12.000000000000004 12.86961364554084,12.000000000000004 C 21.55766519650088,11.999999999999998 27.39996126093298,19.505166496923657 21.777493756594573,23.443296031350947 C 19.329211882382396,25.158139407501768 15.586222427783175,25.28744009397321 9.51727354110616,23.866822442360682 Z

# %% [markdown]
# The following code shows that there is no corner...

# %%
import re

print(svg_xml)


pattern = re.compile('([\d\.]+),([\d\.]+)\s[MCLZ]')
segments = pattern.findall(svg_xml)
svg_iter = re.finditer(pattern, svg_xml)
print()

print("---------control points 1-----------------")
#print(segments)

controlPoints1 = [(float(i[0]), float(i[1])) for i in segments]
print(controlPoints1)
print()
pattern2 = re.compile('C\s([\d\.]+),([\d\.]+)\s([\d\.]+),([\d\.]+)\s')
segments2 = pattern2.findall(svg_xml)
print("---------control points 2-----------------")
#print(segments2)

controlPoints2 = []
for i in segments2:
    controlPoints2.append((float(i[0]), float(i[1])))
    controlPoints2.append((float(i[2]), float(i[3])))  
print(controlPoints2)
print()
pattern3 = re.compile('C\s([\d\.]+),([\d\.]+)\s([\d\.]+),([\d\.]+)\s')
segments3 = pattern3.findall(svg_xml)
print("---------control points 3-----------------")
#print(segments3)
# Out:
# <svg version="1.0" xmlns="http://www.w3.org/2000/svg" height="28" width="28"><path d=" M 9.51727354110616,23.866822442360682 C 7.326773988714548,23.35407099427908 5.080535634789604,22.4805356347896 4.525632754606285,21.925632754606283 C 2.8631039142417585,20.263103914241764 5.922023034797406,19.117247821398927 9.377320857176409,20.10821419798448 C 14.307346962865184,21.52212708120532 20.0,21.23446572137142 20.0,19.571428571428573 C 20.0,15.448883661542762 14.21768735115364,13.80182900831094 9.07712424347698,16.460117503694516 C 7.524168496961943,17.263182130726502 5.971515464059835,17.638182130726502 5.626784170361184,17.293450837027848 C 4.509391136402156,16.176057803068822 4.962136189569638,11.973900681682284 6.525680146231596,8.950340073115797 C 7.848028337137488,6.393200643938476 8.614348031347701,5.998533242264358 12.275680146231595,5.988994336118905 C 14.599056065804218,5.982941220984303 18.1875,5.69906215134539 20.25,5.358151959143543 C 23.575019504115325,4.808560183035496 24.0,4.972855689457036 24.0,6.80788472346307 C 24.0,8.47943353024978 23.18263780528935,8.995855833947624 19.75,9.493101638215052 C 17.4125,9.831707728751054 14.42460457428058,9.97178053355376 13.11023238729018,9.804374537776619 C 11.79586020029978,9.636968541999478 10.52086020029978,10.0625 10.276899053956846,10.750000000000002 C 9.984878902308747,11.57293372230617 10.870687678108958,12.000000000000004 12.86961364554084,12.000000000000004 C 21.55766519650088,11.999999999999998 27.39996126093298,19.505166496923657 21.777493756594573,23.443296031350947 C 19.329211882382396,25.158139407501768 15.586222427783175,25.28744009397321 9.51727354110616,23.866822442360682 Z" /></svg>
#
# ---------control points 1-----------------
# [(9.51727354110616, 23.866822442360682), (4.525632754606285, 21.925632754606283), (9.377320857176409, 20.10821419798448), (20.0, 19.571428571428573), (9.07712424347698, 16.460117503694516), (5.626784170361184, 17.293450837027848), (6.525680146231596, 8.950340073115797), (12.275680146231595, 5.988994336118905), (20.25, 5.358151959143543), (24.0, 6.80788472346307), (19.75, 9.493101638215052), (13.11023238729018, 9.804374537776619), (10.276899053956846, 10.750000000000002), (12.86961364554084, 12.000000000000004), (21.777493756594573, 23.443296031350947), (9.51727354110616, 23.866822442360682)]
#
# ---------control points 2-----------------
# [(7.326773988714548, 23.35407099427908), (5.080535634789604, 22.4805356347896), (2.8631039142417585, 20.263103914241764), (5.922023034797406, 19.117247821398927), (14.307346962865184, 21.52212708120532), (20.0, 21.23446572137142), (20.0, 15.448883661542762), (14.21768735115364, 13.80182900831094), (7.524168496961943, 17.263182130726502), (5.971515464059835, 17.638182130726502), (4.509391136402156, 16.176057803068822), (4.962136189569638, 11.973900681682284), (7.848028337137488, 6.393200643938476), (8.614348031347701, 5.998533242264358), (14.599056065804218, 5.982941220984303), (18.1875, 5.69906215134539), (23.575019504115325, 4.808560183035496), (24.0, 4.972855689457036), (24.0, 8.47943353024978), (23.18263780528935, 8.995855833947624), (17.4125, 9.831707728751054), (14.42460457428058, 9.97178053355376), (11.79586020029978, 9.636968541999478), (10.52086020029978, 10.0625), (9.984878902308747, 11.57293372230617), (10.870687678108958, 12.000000000000004), (21.55766519650088, 11.999999999999998), (27.39996126093298, 19.505166496923657), (19.329211882382396, 25.158139407501768), (15.586222427783175, 25.28744009397321)]
#
# ---------control points 3-----------------

# %%
def end_or_middle_points(svg_path, mode):
    control_points = []
    if mode == "end":
        pattern = re.compile('([\d\.]+),([\d\.]+)\s[MCLZ]')
        segments = pattern.findall(svg_path)
        #svg_iter = re.finditer(pattern, svg_path)
        control_points = [(float(i[0]), float(i[1])) for i in segments]
        #print(control_points)
    elif mode == "mid":
        pattern = re.compile('C\s([\d\.]+),([\d\.]+)\s([\d\.]+),([\d\.]+)\s')
        segments = pattern.findall(svg_path)

        for i in segments:
            control_points.append((float(i[0]), float(i[1])))
            control_points.append((float(i[2]), float(i[3])))
        #print(control_points)
    return control_points
end_points = end_or_middle_points(desc, "end")
print(end_points)
mid_points = end_or_middle_points(desc, "mid")
print(mid_points)

import random
print(random.choice(end_points))
print(random.choice(mid_points))
# Out:
# [(9.51727354110616, 23.866822442360682), (4.525632754606285, 21.925632754606283), (9.377320857176409, 20.10821419798448), (20.0, 19.571428571428573), (9.07712424347698, 16.460117503694516), (5.626784170361184, 17.293450837027848), (6.525680146231596, 8.950340073115797), (12.275680146231595, 5.988994336118905), (20.25, 5.358151959143543), (24.0, 6.80788472346307), (19.75, 9.493101638215052), (13.11023238729018, 9.804374537776619), (10.276899053956846, 10.750000000000002), (12.86961364554084, 12.000000000000004), (21.777493756594573, 23.443296031350947), (9.51727354110616, 23.866822442360682)]
# [(7.326773988714548, 23.35407099427908), (5.080535634789604, 22.4805356347896), (2.8631039142417585, 20.263103914241764), (5.922023034797406, 19.117247821398927), (14.307346962865184, 21.52212708120532), (20.0, 21.23446572137142), (20.0, 15.448883661542762), (14.21768735115364, 13.80182900831094), (7.524168496961943, 17.263182130726502), (5.971515464059835, 17.638182130726502), (4.509391136402156, 16.176057803068822), (4.962136189569638, 11.973900681682284), (7.848028337137488, 6.393200643938476), (8.614348031347701, 5.998533242264358), (14.599056065804218, 5.982941220984303), (18.1875, 5.69906215134539), (23.575019504115325, 4.808560183035496), (24.0, 4.972855689457036), (24.0, 8.47943353024978), (23.18263780528935, 8.995855833947624), (17.4125, 9.831707728751054), (14.42460457428058, 9.97178053355376), (11.79586020029978, 9.636968541999478), (10.52086020029978, 10.0625), (9.984878902308747, 11.57293372230617), (10.870687678108958, 12.000000000000004), (21.55766519650088, 11.999999999999998), (27.39996126093298, 19.505166496923657), (19.329211882382396, 25.158139407501768), (15.586222427783175, 25.28744009397321)]
# (4.525632754606285, 21.925632754606283)
# (23.575019504115325, 4.808560183035496)

# %%
print([(index,value) for index,value in enumerate(svg_iter)])
# Out:
# [(0, <re.Match object; span=(89, 126), match='9.51727354110616,23.866822442360682 C'>), (1, <re.Match object; span=(198, 236), match='4.525632754606285,21.925632754606283 C'>), (2, <re.Match object; span=(312, 349), match='9.377320857176409,20.10821419798448 C'>), (3, <re.Match object; span=(410, 435), match='20.0,19.571428571428573 C'>), (4, <re.Match object; span=(496, 533), match='9.07712424347698,16.460117503694516 C'>), (5, <re.Match object; span=(608, 646), match='5.626784170361184,17.293450837027848 C'>), (6, <re.Match object; span=(721, 758), match='6.525680146231596,8.950340073115797 C'>), (7, <re.Match object; span=(831, 869), match='12.275680146231595,5.988994336118905 C'>), (8, <re.Match object; span=(932, 957), match='20.25,5.358151959143543 C'>), (9, <re.Match object; span=(1018, 1041), match='24.0,6.80788472346307 C'>), (10, <re.Match object; span=(1100, 1125), match='19.75,9.493101638215052 C'>), (11, <re.Match object; span=(1187, 1224), match='13.11023238729018,9.804374537776619 C'>), (12, <re.Match object; span=(1287, 1326), match='10.276899053956846,10.750000000000002 C'>), (13, <re.Match object; span=(1401, 1439), match='12.86961364554084,12.000000000000004 C'>), (14, <re.Match object; span=(1514, 1553), match='21.777493756594573,23.443296031350947 C'>), (15, <re.Match object; span=(1629, 1666), match='9.51727354110616,23.866822442360682 Z'>)]

# %%
plt.imshow(bw)
#list_of_control_points = []
# Iterate over path curves
for curve in path:
    for segment in curve:
        # M
        if segment.is_corner:
            # L
            #list_of_control_points.append((segment.c[0],segment.c[1]))
            #list_of_control_points.append((segment.end_point[0],segment.end_point[1]))
            print("got a corner")
        else:
            # C
            #list_of_control_points.append((segment.c1[0],segment.c1[1]))
            #list_of_control_points.append((segment.c2[0],segment.c2[1]))
            plt.plot(segment.c1[0]-0.5,segment.c1[1]-0.5,marker = ".",color = "r")
            plt.plot(segment.c2[0]-0.5,segment.c2[1]-0.5,marker = ".",color = "r")
            #list_of_control_points.append((segment.end_point[0],segment.end_point[1]))
            plt.plot(segment.end_point[0]-0.5,segment.end_point[1]-0.5,marker = ".",color = "g")
    # Z
plt.title("mid (red) and end (green) Points")
# Out:
# Text(0.5, 1.0, 'mid (red) and end (green) Points')

# %% [markdown]
# # 2. Try attention map
# * Question. This attention map is computed based on which model?
#
#     From *predictor.model load based on config.py*
#
# * Only the method *input_reshape_and_normalize_images* from *attention_maps.py* was used, but other 4000 lines was unused...

# %%
from attention_manager import AttentionManager
print(x_test.shape)
attention = AttentionManager()
xai_imgs = attention.compute_attention_maps(x_test)

print(attention.score)

print(xai_imgs.shape)

num_img = 7
composite_img = np.zeros((28*2, 28*num_img))
for i in range(num_img):
    
    composite_img[0:28,28*i:28*(i+1)] = x_test[i]/256
    composite_img[28:,28*i:28*(i+1)] = xai_imgs[i]
print(x_test.max())
print(xai_imgs.max())
print(xai_imgs[1].max())
# Out:
# (100, 28, 28)
# <tf_keras_vis.utils.scores.CategoricalScore object at 0x7fcc07eb8be0>
# (100, 28, 28)
# 255
# 0.99999285
# 0.033639837

# %% [markdown]
# print(composite_img)
# plt.imshow(composite_img)
# plt.axis("off")

# %%
plt.imshow(composite_img) 
plt.axis("off")
# Out:
# (-0.5, 195.5, 55.5, -0.5)

# %% [markdown]
# Some attention maps is missing, since its pixels are really low somehow...

# %%
plt.subplot(1,2,1)
plt.imshow(xai_imgs[1])
print(xai_imgs[1].max())
plt.subplot(1,2,2)
plt.imshow(xai_imgs[6])
print(xai_imgs[6].max())
# Out:
# 0.033639837
# 0.04272662

# %% [markdown]
# # 3. Try mutation

# %%
from predictor import Predictor
# predict something
for img_id in range(20):
    x_temp =  np.reshape(x_test[img_id], (-1, 28, 28, 1))
    print(Predictor.predict_single(x_temp,y_test[img_id]))
# Out:
# 1/1 [==============================] - 0s 332ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 28ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 26ms/step
# (8, -1.0)
# 1/1 [==============================] - 0s 28ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 28ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 28ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 29ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 28ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 29ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 33ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 30ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 31ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 31ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 30ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 28ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 31ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 29ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 29ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 27ms/step
# (5, 1.0)
# 1/1 [==============================] - 0s 28ms/step
# (5, 1.0)

# %% [markdown]
# Mutation file
# ```python
# mutation_manager.mutate()
# mutation_manager.generate()
# ```
# are called in
# ```python
# digit_mutation.py
# ```
# "mutate" mutates one coordinate of vertex in one image
# "generate" generates a pair of images based on one image
#
#
#
# Parameters:
# ```python
# # MUTATION_TYPE = "random"
# MUTATION_TYPE = "attention-based"
# # range of the mutation
# MUTLOWERBOUND = 0.01
# MUTUPPERBOUND = 0.6
# # mutation operator probability
# MUTOPPROB = 0.5
# MUTOFPROB = 0.5
# ```

# %%
from digit_mutator import DigitMutator
from population import *

POPSIZE = 1
x_test, y_test = load_dataset()

pop = Population()
print(f" Population size {pop.size}")
digit_ini = [ind.purified for ind in pop.population_to_mutate]
for idx in range(1):
    digit_cur = [ind.purified for ind in pop.population_to_mutate]

    pop.evaluate_population(idx)
    print([ind.confidence for ind in pop.population_to_mutate])
    pop.mutate()

    #print([get_distance(digit_ini[i], digit_cur[i]) for i in range(POPSIZE)])

print(f" Misclass number {pop.misclass_number}")

mnist_original = generate_digit(seed)# create Mnist member based on the seed and x_test
digit1, digit2, distance_inputs = DigitMutator(generate_digit(seed)).generate()
plt.imshow(mnist_original.purified.reshape(28, 28))
# Out:
#  Population size 100
# 4/4 [==============================] - 0s 3ms/step
# [1.0, 1.0, 1.0, 1.0, 0.9999966, 1.0, 0.99999994, 1.0, 0.99999946, 0.9999316, 1.0, 0.99996454, 1.0, 0.9996228, 0.99999976, 0.9976917, 1.0, 1.0, 1.0, 0.99992037, 0.9999998, 0.9996637, 0.9999995, 0.9990898, 1.0, 0.9999998, 0.9946948, 1.0, 1.0, 0.9999986, 1.0, 0.99999976, 1.0, 0.9999993, 1.0, 0.9999828, 0.9999997, 0.9999677, 0.9999977, 0.99999994, 0.9992981, 0.99999917, 0.99999934, 1.0, 0.9999566, 1.0, 0.9999998, 0.99856603, 0.9999745, 1.0, 1.0, 0.9999425, 1.0, 1.0, 0.99999976, 1.0, 1.0, 1.0, 0.9999997, 0.9999435, 1.0, 0.9999996, 0.9999349, 0.9999977, 0.99997336, 1.0, 1.0, 0.9982515, 0.9998616, 1.0, 0.9999992, 1.0, 0.99999976, 1.0, 0.9999976, 0.99999934, 0.9999997, 1.0, 0.9999989, 0.9999723, 1.0, 0.99999976, 0.9998866, 0.9999278, 1.0, 0.99999523, 0.9999998, 0.99997526, 1.0, 0.9999414, 1.0, 1.0, 0.9999996, 0.9889833, 0.99999905, 0.9999998, 1.0, 0.9999974]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[45], line 15
#      13     pop.evaluate_population(idx)
#      14     print([ind.confidence for ind in pop.population_to_mutate])
# ---> 15     pop.mutate()
#      17     #print([get_distance(digit_ini[i], digit_cur[i]) for i in range(POPSIZE)])
#      19 print(f" Misclass number {pop.misclass_number}")
#
# File ~/Projects/deepjanus-pri/XMutant-MNIST/population.py:83, in Population.mutate(self)
#      81 batch_individual = [ind for ind in self.population_to_mutate]
#      82 for ind in batch_individual:
# ---> 83     DigitMutator(ind).mutate()
#
# File ~/Projects/deepjanus-pri/XMutant-MNIST/digit_mutator.py:94, in DigitMutator.mutate(self)
#      92 counter_mutations += 1
#      93 #mutant_vector = mutation_manager.mutate(self.digit.xml_desc, mutation, counter_mutations/20)
# ---> 94 mutant_vector = mutation_manager.mutate(self.digit.purified, self.digit.xml_desc, self.digit.attention, mutation, MUTEXTENT)#counter_mutations / 20)
#      95 mutant_xml_desc = vectorization_tools.create_svg_xml(mutant_vector)
#      96 rasterized_digit = rasterization_tools.rasterize_in_memory(mutant_xml_desc)
#
# UnboundLocalError: local variable 'mutation' referenced before assignment

# %%
plt.imshow(digit1.purified.reshape(28, 28))

# %%
plt.imshow(digit2.purified.reshape(28, 28))

# %% [markdown]
# * These two generated graphs look very similiar but criterion in DigitMutator.generate() is the difference between the two graphs larger than 0.
# * 50% with operator1 and 50% with operator2, which are two different patterns
#  * operator1 changes all vertexs marked with "[MCLZ]"
#  * operator2 changes only vertex marked with "M"
# * select a vertex and apply displacement of
#
# ```
# +/- uniform(MUTLOWERBOUND, MUTUPPERBOUND)
# ```

# %%
from utils import get_distance
print(get_distance(digit1.purified,digit2.purified))
print(get_distance(mnist_original.purified,digit1.purified))
print(get_distance(mnist_original.purified,digit2.purified))
# Out:
# 0.019996155
# 0.009605842
# 0.011091873

# %% [markdown]
# ## Attention-based mutation
# Weights and probabilities are calculated for each vertex in SVG.
# Note here weight is based on the sum of the pixel values in the square area centered on the vertex. Moreover the size of square is fixed 3 or 5.
# TO-DO: Let's try some more reasonable way... like weighted K-means.
